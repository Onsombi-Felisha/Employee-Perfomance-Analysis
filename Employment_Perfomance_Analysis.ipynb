# %% [markdown]
# # PROJECT SUMMARY
#
# The project is set to analyse the employee perfomance in INX Future Inc, which is a data analytics and automation solution provider.For the past 5 years, the company is rated among the best 20 employees. However, recently the company has seen the employee performance indexes are not healthy and this is becoming a growing concern among the top management. There has been increased escalations on service delivery and client satisfaction levels came down by 8 percentage points. The CEO decided to initiate a data science project , which aims to analyse the employee perfomance. The following goals and insights are expected from the project :
# * Department wise performances
# * Top 3 Important Factors affecting employee performance
# * A trained model which can predict the employee performance based on factors as inputs. This will be used to hire employees
# * Recommendations to improve the employee performance based on insights from analysis.
#
# The data is made up of 28 columns and 1200 rows. 19 of the columns are numerical while the rest are categorical in nature. The EmpID is dropped since it does not help in our analysis.
# The dataset contains no missing or duplicate values.
# The numerical Columns include:
# *   Age
# *  DistanceFromHome
# *   EmpEucationLevel',
# *  EmpEnvironmentSatisfaction
# *  EmpHourlyRate
# * EmpJobInvolvement
# *  EmpJobLevel
# *  EmpJobSatisfaction
# *  NumCompaniesWorked
# *  EmpLastSalaryHikePercent
# *  EmpRelationshipSatisfaction
# *  TotalWorkExperienceInYears
# *  TrainingTimesLastYear
# *  EmpWorkLifeBalance
# *  ExperienceYearsAtThisCompany
# *  ExperienceYearsInCurrentRole
# *  YearsSinceLastPromotion
# *  YearsWithCurrManager
# *  PerformanceRating
#
# The Categorical Columns include:
# *  Gender
# * EducationBackground
# * MaritalStatus
# * EmpDepartment
# * EmpJobRole
# * BusinessTravelFrequency
# * OverTime
# * Attrition

# %% [markdown]
# ## REQUIREMENT
#
# The data was obtained from IABAC from the following link:
# http://data.iabac.org/exam/p2/data/INX_Future_Inc_Employee_Performance_CDS_Project2_Data_V1.8.xls
#
#
# The whole project was done in Jupiter notebook with python platform.

# %% [markdown]
# ## ANALYSIS
#
# The Dataset went through univariate and bivariate analysis to get more understanding on the data. Visualisations through histograms,pie charts and histoplots and coorelation analysis. Analysis per department by perfomance rating to satisfy the second goal.
#
# ### UNIVARIATE ANALYSIS
# #### ENCODED COLUMNS
# 1.   Education Level
#
# 12.3% of employees  have below college education , 19.9% have a college education level, 37.4 %have bachelor's degree and 26.8% have master's degree, 3.8% have Phd and 2.5% have others
# 2.   Environment Satisfaction
#
# 19.2% of employees have low rating on environment satisfaction , 20.2% have a medium rating on environment satisfaction, 30.6 % have a high rating on environment satisfaction and 30.1% have a very high rating on environment satisfaction
# 3.   Job Involvement
#
# 5.8% of the employees have a low rating on job involvement , 24.5% have a medium rating on job involvement, 60.3% have a high rating on job involvement and 9.3% have a very high rating on job involvement
# 4.   Job Satisfaction
#
# 19.2% of the employees have a low level of job satisfaction, 19.8% have a medium level of job satisfaction, 29.5% have a high level of job satisfaction and 31.5% have a very high level of job satisfaction
# 5.   Relationship Satisfaction
#
# 18.3% of the employees have low relationship satisfaction , 20.6% have a medium relationship satisfaction, 31.6% have a high relationship satisfaction and 29.6% have a very high relationship satisfaction
# 6.   Work Life Balance
#
# 5.3%  have a bad work life balance , 60.6% have a better work life balance , 24.5% have a very good work life balance and 9.6% have the best work life balance
# 7.   Perfomance Rating
#
# No employee has a low perfomance rating , 16.2% have a medium perfomance rating , 72.8% have a high perfomance rating and 11.0% have a very high perfomance rating
# ####CATEGORICAL COLUMNS
#
# 1. The Gender distribution is  725 of Male employees and 475 of Female employees in the company.
#
# 2. The number of the educational backgrounds present in the employees is six backgrounds.That is Marketing, Life Sciences,Human Resources, Medical, Technical Degree, and Other.
#
# 3. Business Travel Frequency has 3 unique values with 900 employees have travelled rarely , while the least which is about 100 employees have not traveled and 2000 employees have travelled frequently
# There are 19 unique values in the job role column.
#
# 4. The overall number of employees doing overtime is 360
#
# 5. The 1000 of employees are not having attrition in their work, while only 200 of employees in the company have attrition in their work
#
# ####NUMERICAL COLUMNS
# 1. The age distribution is starting from 18 to 60 where the most of the employees are lying between 30 to 40 age count.
#
#
# 2. The distance from home to office is distributing from 0 unit to 30 unit which can be kilometre or mile. The most of the employees are coming from the range of 0 to 5 units.
#
# 3. Employees are worked in the multiple companies up to 8 companies where most of the employees worked up to 2 companies before getting to work here.
#
# 4. The hourly rate range is 65 to 95 for majority employees work in this company.
#
# 5. Most of Employees work up to 5 years in this company.
#
# 6. Most of the employees get 11% to 15% of salary hike in this company.
# ### BIVARIATE ANALYSIS
# #### DEPARTMENT WISE PERFORMANCE
#
#
# #### COORELATION ANALYSIS
# The Total years of experience and job level are having the higher correlation when comparing to all features.
#
# Experience years at this company and years with the current manager has the second higher relation between these features.
#
# Experience years at this company and experience in the current role makes the sense of correlation.
#
# People who have more experience with the company has the more probability to get the promotion from the correlation between them.
#
# In this plot, the age has the important role in the total number of work experience of an employee where it is a universal truth.
# ### MACHINE LEARNING MODEL
# The Target variable in this case will be the Perfomance Rating. We encode the data using the label encoder then scale it.
# The machine learning models used in this project are:
#
#
# 1.   Random Forest classifier
# 2.   Decision Tree Classifier
#
# The predicted data and test data achieved the accuracy rate of,
# Random Forest classifier: 91%
# Decision Tree Classifier: 87%

# %% [markdown]
# ## SUMMARY
# ###DEPARTMENT WISE PERFORMANCE
# Data Science and Development departments have the highest mean perfomance rating of 3 while the rest of the departments have a mean perfomance rating of 2.
#
# In all departments those with a high salary percentage have a high perfomance rating.
#
#
# Also a high level of environment satisfaction translates to high perfomance rating..
#
# **Sales Department**
#
# The Performace rating level 3 (High) is more in the sales department.
#
# The male employees in the sales departmnent have a performance rating that is little bit higher compared to female.
#
# Divorced have a rating of 3 while the married and single have a less rating.
#
# The total work experience does not count the performance rating.
#
# **Human Resources Department**
#
# Most employees employees have a level 3 performance.
#
# The older people are performing low in this department.
#
# The female employees in HR department doing really well in their performance.
# The total work experience does matter to performance in this department.
#
# **Development Department**
#
#  The largest number of employees are level 3 performers.
#
#  Managers have the highest rating of 3
#
#  The gender-based performance is nearly same for both.
#
# **Data Science Department**
#
# The highest average of level 3 performance is in data science department.
#
# Businees Analyst in the department have highest rating
#
# The overall performance is higher compared to all departments.
#
# Male employees are doing good in this department.
#
# **Research & Development Department**
#
# The age factor is not deviating from the level of performance here where different employees with different age are there in every level of performance. The R&D has the good female employees in their performance.
#
# **Finance Department**
#
# Male employees have a higher rating than their female counterparts.
#
# Most employees have a rating of 3.
#
#
# ### COORELATION ANALYSIS
#
# The Total years of experience and job level are having the higher correlation when comparing to all features.
#
# Experience years at this company and years with the current manager has the second higher relation between these features.
#
# Experience years at this company and experience in the current role makes the sense of correlation.
#
# People who have more experience with the company has the more probability to get the promotion from the correlation between them.
#
# In this plot, the age has the important role in the total number of work experience of an employee where it is a universal truth.
# ###TOP 3 IMPORTANT FACTORS
# One of the goals of this project is to find the important feature affecting the performance rating. The important features were predicted using the machine learning model(Random Forest Classifier) feature importance technique.From it the Machine Learning Model concluded that the following are the important features:
# 1. Employee Salary Hike Percentage
# 2. Employee Environment Satisfaction
# 3. Years Since the last Promotion
#
# ###A TRAINED MODEL WHICH CAN PREDICT THE EMPLOYEE PERFORMANCE BASED ON FACTORS AS INPUTS
#
# A machine learning model was trained using the data and the following are the accuracy scores:
# 1.   Random Forest classifier - 91%
# 2.   Decision Tree Classifier - 87%
#
# Random Forest Classifier had the highest accuracy score(91%) thereforesuitable for training and developing the model.
#
#
# ### RECOMMENDATIONS TO IMPROVE THE EMPLOYEE PERFORMANCE
# The recommendations are as follows:
#
# 1. To increase the employee salary hike percentage, salary hike will boost the employees morale thus increasing perfomance
# 2. The company needs to focus on the environment satisfaction, give the employees a proper environment that they are comfortable in  and are feeling positive.
# 3. Promotion will help the employees to achieve more performance by giving the chance to be more responsible and acquire leadership qualities.
# 4. Employee's work-life balance affects the performance rating. Therefore encourage and train employees on how to achieve proper work life balance to enhance employee’s perfomance in the company

# %%
#Importing the libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %% [markdown]
# # DATA

# %% [markdown]
# ##Data Loading and Preprocessing

# %%
#Loading the data
from google.colab import files

data = files.upload()
# Out:
#      <input type="file" id="files-85fa9ce9-5d79-43ca-84ea-e811cd9432e3" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-85fa9ce9-5d79-43ca-84ea-e811cd9432e3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#Loading the data to dataframe
df = pd.read_csv("Employee Perfomance Analysis.csv")

# %%
#Show top 5 rows
df.head()
# Out:
#   EmpNumber  Age Gender EducationBackground MaritalStatus    EmpDepartment  \
# 0  E1001000   32   Male           Marketing        Single            Sales
# 1  E1001006   47   Male           Marketing        Single            Sales
# 2  E1001007   40   Male       Life Sciences       Married            Sales
# 3  E1001009   41   Male     Human Resources      Divorced  Human Resources
# 4  E1001010   60   Male           Marketing        Single            Sales
#
#         EmpJobRole BusinessTravelFrequency  DistanceFromHome  \
# 0  Sales Executive           Travel_Rarely                10
# 1  Sales Executive           Travel_Rarely                14
# 2  Sales Executive       Travel_Frequently                 5
# 3          Manager           Travel_Rarely                10
# 4  Sales Executive           Travel_Rarely                16
#
#    EmpEducationLevel  ...  EmpRelationshipSatisfaction  \
# 0                  3  ...                            4
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1200 entries, 0 to 1199
# Data columns (total 28 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   EmpNumber                     1200 non-null   object
#  1   Age                           1200 non-null   int64
#  2   Gender                        1200 non-null   object
#  3   EducationBackground           1200 non-null   object
#  4   MaritalStatus                 1200 non-null   object
#  5   EmpDepartment                 1200 non-null   object
#  6   EmpJobRole                    1200 non-null   object
#  7   BusinessTravelFrequency       1200 non-null   object
#  8   DistanceFromHome              1200 non-null   int64
#  9   EmpEducationLevel             1200 non-null   int64
#  10  EmpEnvironmentSatisfaction    1200 non-null   int64
#  11  EmpHourlyRate                 1200 non-null   int64
# ...

# %%
#check for duplicates
df.duplicated().sum()
# Out:
# 0

# %%
#Checking for missing values
df.isnull().sum()
# Out:
# EmpNumber                       0
# Age                             0
# Gender                          0
# EducationBackground             0
# MaritalStatus                   0
# EmpDepartment                   0
# EmpJobRole                      0
# BusinessTravelFrequency         0
# DistanceFromHome                0
# EmpEducationLevel               0
# EmpEnvironmentSatisfaction      0
# EmpHourlyRate                   0
# EmpJobInvolvement               0
# EmpJobLevel                     0
# EmpJobSatisfaction              0
# NumCompaniesWorked              0
# OverTime                        0
# EmpLastSalaryHikePercent        0
# EmpRelationshipSatisfaction     0
# TotalWorkExperienceInYears      0
# TrainingTimesLastYear           0
# EmpWorkLifeBalance              0
# ExperienceYearsAtThisCompany    0
# ExperienceYearsInCurrentRole    0
# YearsSinceLastPromotion         0
# YearsWithCurrManager            0
# Attrition                       0
# ...

# %%
# Dropping the  "EmpNumber" Column
df = df.drop('EmpNumber', axis=1)

# %%
df.head()
# Out:
#    Age Gender EducationBackground MaritalStatus    EmpDepartment  \
# 0   32   Male           Marketing        Single            Sales
# 1   47   Male           Marketing        Single            Sales
# 2   40   Male       Life Sciences       Married            Sales
# 3   41   Male     Human Resources      Divorced  Human Resources
# 4   60   Male           Marketing        Single            Sales
#
#         EmpJobRole BusinessTravelFrequency  DistanceFromHome  \
# 0  Sales Executive           Travel_Rarely                10
# 1  Sales Executive           Travel_Rarely                14
# 2  Sales Executive       Travel_Frequently                 5
# 3          Manager           Travel_Rarely                10
# 4  Sales Executive           Travel_Rarely                16
#
#    EmpEducationLevel  EmpEnvironmentSatisfaction  ...  \
# 0                  3                           4  ...
# 1                  4                           4  ...
# ...

# %%
df.shape
# Out:
# (1200, 27)

# %%
#Identify numerical Columns
nums_cols= df.select_dtypes(include=np.number).columns
nums_cols
# Out:
# Index(['Age', 'DistanceFromHome', 'EmpEducationLevel',
#        'EmpEnvironmentSatisfaction', 'EmpHourlyRate', 'EmpJobInvolvement',
#        'EmpJobLevel', 'EmpJobSatisfaction', 'NumCompaniesWorked',
#        'EmpLastSalaryHikePercent', 'EmpRelationshipSatisfaction',
#        'TotalWorkExperienceInYears', 'TrainingTimesLastYear',
#        'EmpWorkLifeBalance', 'ExperienceYearsAtThisCompany',
#        'ExperienceYearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager', 'PerformanceRating'],
#       dtype='object')

# %%
#Identify categorical columns
cat_cols= df.select_dtypes(include='object').columns
cat_cols
# Out:
# Index(['Gender', 'EducationBackground', 'MaritalStatus', 'EmpDepartment',
#        'EmpJobRole', 'BusinessTravelFrequency', 'OverTime', 'Attrition'],
#       dtype='object')

# %%
#Identify encoded columns
encoded = df[['EmpEducationLevel', 'EmpEnvironmentSatisfaction', 'EmpJobInvolvement',
                   'EmpJobSatisfaction', 'PerformanceRating', 'EmpRelationshipSatisfaction',
                   'EmpWorkLifeBalance']]
encoded
# Out:
#       EmpEducationLevel  EmpEnvironmentSatisfaction  EmpJobInvolvement  \
# 0                     3                           4                  3
# 1                     4                           4                  3
# 2                     4                           4                  2
# 3                     4                           2                  2
# 4                     4                           1                  3
# ...                 ...                         ...                ...
# 1195                  1                           4                  4
# 1196                  2                           4                  4
# 1197                  1                           4                  4
# 1198                  3                           4                  2
# 1199                  2                           1                  3
#
#       EmpJobSatisfaction  PerformanceRating  EmpRelationshipSatisfaction  \
# ...

# %%
#Unique values of gender column
df['Gender'].value_counts()
# Out:
# Male      725
# Female    475
# Name: Gender, dtype: int64

# %%
#Unique values of MaritalStatus column
df['MaritalStatus'].value_counts()
# Out:
# Married     548
# Single      384
# Divorced    268
# Name: MaritalStatus, dtype: int64

# %%
#Unique values of EmpDepartment column
df['EmpDepartment'].value_counts()
# Out:
# Sales                     373
# Development               361
# Research & Development    343
# Human Resources            54
# Finance                    49
# Data Science               20
# Name: EmpDepartment, dtype: int64

# %%
df.describe()
# Out:
#                Age  DistanceFromHome  EmpEducationLevel  \
# count  1200.000000       1200.000000         1200.00000
# mean     36.918333          9.165833            2.89250
# std       9.087289          8.176636            1.04412
# min      18.000000          1.000000            1.00000
# 25%      30.000000          2.000000            2.00000
# 50%      36.000000          7.000000            3.00000
# 75%      43.000000         14.000000            4.00000
# max      60.000000         29.000000            5.00000
#
#        EmpEnvironmentSatisfaction  EmpHourlyRate  EmpJobInvolvement  \
# count                 1200.000000    1200.000000        1200.000000
# mean                     2.715833      65.981667           2.731667
# std                      1.090599      20.211302           0.707164
# min                      1.000000      30.000000           1.000000
# 25%                      2.000000      48.000000           2.000000
# ...

# %% [markdown]
# #### OBSERVATIONS
# 1.   There are 28 columns in this datasets
# 2.   19 columns out of 28 columns are numericals while strings are strings
# 1. The dataset has no missing values or duplicates
# 1. The "EmpNumber' column does not provide any helpful information therefore dropped
# 2. The distribution of gender in the Company is as folllows: Male(725), Females(475)
# 1. Married Employees (548), while singles(384),Divorced(268)
# 2. The Company has 6 departments as follows: Sales, Development, Research and Development, Human Resource , Finance and Data Science.
# 1. The eldest employee is 60 years while the youngest  is 18 years , the mean of age of the employees is 36 years.
# 1.Some columns such as :EmpEducationLevel,EmpEnvironmentSatisfaction,EmpJobInvolvement,EmpJobSatisfaction,PerformanceRating,RelationshipSatisfaction,EmpWorkLifeBalance are already encoded with values from one to five.
#
# 1.   EmphourlyRate ranges from 30 to 100 and its average value is 65.981.
# 2.   The Average EmpJobInvolvement is 2.73 which suggests that most of the employees are Having 'High' EmpJobInvolvement than the ones with 'Low','medium' and 'Very High' EmpJobInvolvement.
# 3.Average Value of EmpJobLevel is 2.067500 which is almost tending towards 2.From this one could infer that most of theemployees fall under EmpJobLevel'2'.
# 4.Mean EmpLastSalaryHikePercent is 15.225 which suggests that most of the employees and std is 3.65 i.e most of the EmpLastSalaryHikePercent values are in between 12 and 18.
# 5.Mean TotalWorkExperienceInYears is 11.33 yrs.
# 6.Mean EmpWorkLifeBalance is 2.744167 which almost tends to 3.It means that most of the Employees fall under 'Better' EmpWorkLifeBalance.
# 7.Mean ExperienceYearsAtThisCompany value is 7.077500 and std is 6.236899.
# 8.Mean ExperienceYearsInCurrentRole is 4.291667 yrs which suggest that most of the employees are almost highly expertised in the role/job code they are working in.
# 9.Mean Performance Rating is 2.948333 which almost raring 3.It is inferred from the mean rating value that most of the employees have got 3 as their performance rating.

# %% [markdown]
# # ANALYSIS

# %% [markdown]
# ##Unvivariate Analysis
# Here will analayse each column individually.

# %%
#Distribution of encoded columns
encoded = df[['EmpEducationLevel', 'EmpEnvironmentSatisfaction', 'EmpJobInvolvement',
                   'EmpJobSatisfaction', 'PerformanceRating', 'EmpRelationshipSatisfaction',
                   'EmpWorkLifeBalance']]
encoded
# Out:
#       EmpEducationLevel  EmpEnvironmentSatisfaction  EmpJobInvolvement  \
# 0                     3                           4                  3
# 1                     4                           4                  3
# 2                     4                           4                  2
# 3                     4                           2                  2
# 4                     4                           1                  3
# ...                 ...                         ...                ...
# 1195                  1                           4                  4
# 1196                  2                           4                  4
# 1197                  1                           4                  4
# 1198                  3                           4                  2
# 1199                  2                           1                  3
#
#       EmpJobSatisfaction  PerformanceRating  EmpRelationshipSatisfaction  \
# ...

# %%
#Distribution of encoded columns
#Create Pie chart to showcase the distribution
plt.figure(figsize= (20, 15))
for idx, col in enumerate(encoded):
    plt.subplot(3, 4, idx+1,)
    plt.suptitle("Pie Chart Distribution", fontsize=20, x=0.5, y=1)
    data = df[col].value_counts()
    wedges, texts, autotexts = plt.pie(data, labels=None, autopct='%1.1f%%', startangle=90)

    # Create a custom legend with percentages
    legend_labels = [f"{label}: {percent:.1f}%" for label, percent in zip(data.index, data / data.sum() * 100)]
    plt.legend(legend_labels, loc='center left', bbox_to_anchor=(1, 0.5))

    plt.title(f"{col} Distribution", fontsize=12)
    plt.axis('equal')  # Equal aspect ratio ensures that pie charts are circular
    plt.savefig('Distribution of Encoded Columns')

plt.show()

# %% [markdown]
# Under the encoded Columns
#
# 1.   Education Level
#
# 12.3% of employees  have below college education , 19.9% have a college education level, 37.4 %have bachelor's degree and 26.8% have master's degree, 3.8% have Phd and 2.5% have others
# 2.   Environment Satisfaction
#
# 19.2% of employees have low rating on environment satisfaction , 20.2% have a medium rating on environment satisfaction, 30.6 % have a high rating on environment satisfaction and 30.1% have a very high rating on environment satisfaction
# 3.   Job Involvement
#
# 5.8% of the employees have a low rating on job involvement , 24.5% have a medium rating on job involvement, 60.3% have a high rating on job involvement and 9.3% have a very high rating on job involvement
# 4.   Job Satisfaction
#
# 19.2% of the employees have a low level of job satisfaction, 19.8% have a medium level of job satisfaction, 29.5% have a high level of job satisfaction and 31.5% have a very high level of job satisfaction
# 5.   Relationship Satisfaction
#
# 18.3% of the employees have low relationship satisfaction , 20.6% have a medium relationship satisfaction, 31.6% have a high relationship satisfaction and 29.6% have a very high relationship satisfaction
# 6.   Work Life Balance
#
# 5.3%  have a bad work life balance , 60.6% have a better work life balance , 24.5% have a very good work life balance and 9.6% have the best work life balance
# 7.   Perfomance Rating
#
#
# No employee has a low perfomance rating , 16.2% have a medium perfomance rating , 72.8% have a high perfomance rating and 11.0% have a very high perfomance rating

# %%
nums_cols =['Age', 'DistanceFromHome', 'EmpHourlyRate','EmpJobLevel','NumCompaniesWorked',
            'EmpLastSalaryHikePercent', 'TotalWorkExperienceInYears', 'TrainingTimesLastYear',
            'ExperienceYearsAtThisCompany','ExperienceYearsInCurrentRole', 'YearsSinceLastPromotion',
            'YearsWithCurrManager', ]
fig, axes = plt.subplots(nrows=30, ncols=2)
fig.set_size_inches(50,300)
for i, val in enumerate(nums_cols):
    a = sns.histplot(df[val], ax=axes[i][0])
    a.set_title(val, fontsize=20)
    a = sns.boxplot(df[val], orient = 'v', ax = axes[i][1])
    a.set_title(val, fontsize=20)
    plt.savefig('Distribution of Numerical Columns')
plt.show()

# %% [markdown]
# ####OBSERVATIONS
# The age distribution is starting from 18 to 60 where the most of the employees are lying between 30 to 40 age count.
#
#
# The distance from home to office is distributing from 0 unit to 30 unit which can be kilometre or mile. The most of the employees are coming from the range of 0 to 5 units.
#
# Employees are worked in the multiple companies up to 8 companies where most of the employees worked up to 2 companies before getting to work here.
#
# The hourly rate range is 65 to 95 for majority employees work in this company.
#
# Most of Employees work up to 5 years in this company.
#
# Most of the employees get 11% to 15% of salary hike in this company.

# %%
# Distribution for categorical columns

plt.figure(figsize=(20, 50))
for idx, col in enumerate(cat_cols):
    plt.subplot(8, 1, idx+1)
    plt.suptitle("Plot Value Count", fontsize=20, x=0.5, y=1)
    sns.countplot(data=df, x=col, palette='viridis')
    plt.title(f"{col} Distribution", fontsize=18)
    plt.savefig('Distribution of Categorical Columns')
    plt.tight_layout()
# Out:
# <ipython-input-296-0c41a3e301ae>:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x=col, palette='viridis')
# <ipython-input-296-0c41a3e301ae>:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x=col, palette='viridis')
# <ipython-input-296-0c41a3e301ae>:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x=col, palette='viridis')
# <ipython-input-296-0c41a3e301ae>:7: FutureWarning:
#
# ...

# %% [markdown]
# The Gender distribution is  725 of Male employees and 475 of Female employees in the company.
#
# The number of the educational backgrounds present in the employees is six backgrounds.That is Marketing, Life Sciences,Human Resources, Medical, Technical Degree, and Other.
#
# Business Travel Frequency has 3 unique values with 900 employees have travelled rarely , while the least which is about 100 employees have not traveled and 2000 employees have travelled frequently
# There are 19 unique values in the job role column.
#
# The overall number of employees doing overtime is 360
#
# The 1000 of employees are not having attrition in their work, while only 200 of employees in the company have attrition in their work

# %% [markdown]
# ##Bivariate Analysis
#
# Here study on Department wise Perfomances and cooorelation between features will be studied.

# %%
print(df.groupby('EmpDepartment').describe()['PerformanceRating'])
# Out:
#                         count      mean       std  min  25%  50%  75%  max
# EmpDepartment
# Data Science             20.0  3.050000  0.394034  2.0  3.0  3.0  3.0  4.0
# Development             361.0  3.085873  0.388508  2.0  3.0  3.0  3.0  4.0
# Finance                  49.0  2.775510  0.586846  2.0  2.0  3.0  3.0  4.0
# Human Resources          54.0  2.925926  0.544331  2.0  3.0  3.0  3.0  4.0
# Research & Development  343.0  2.921283  0.559016  2.0  3.0  3.0  3.0  4.0
# Sales                   373.0  2.860590  0.555400  2.0  3.0  3.0  3.0  4.0

# %%
print(df.groupby('EmpDepartment').describe()['PerformanceRating'])
# Out:
#                         count      mean       std  min  25%  50%  75%  max
# EmpDepartment
# Data Science             20.0  3.050000  0.394034  2.0  3.0  3.0  3.0  4.0
# Development             361.0  3.085873  0.388508  2.0  3.0  3.0  3.0  4.0
# Finance                  49.0  2.775510  0.586846  2.0  2.0  3.0  3.0  4.0
# Human Resources          54.0  2.925926  0.544331  2.0  3.0  3.0  3.0  4.0
# Research & Development  343.0  2.921283  0.559016  2.0  3.0  3.0  3.0  4.0
# Sales                   373.0  2.860590  0.555400  2.0  3.0  3.0  3.0  4.0

# %% [markdown]
# ###Sales Department

# %%
Sales_Department = df[df.EmpDepartment == 'Sales'] # Slicing the all coloums of Sales Row
Sales_Department.head()
# Out:
#    Age Gender EducationBackground MaritalStatus EmpDepartment  \
# 0   32   Male           Marketing        Single         Sales
# 1   47   Male           Marketing        Single         Sales
# 2   40   Male       Life Sciences       Married         Sales
# 4   60   Male           Marketing        Single         Sales
# 6   50   Male           Marketing       Married         Sales
#
#              EmpJobRole BusinessTravelFrequency  DistanceFromHome  \
# 0       Sales Executive           Travel_Rarely                10
# 1       Sales Executive           Travel_Rarely                14
# 2       Sales Executive       Travel_Frequently                 5
# 4       Sales Executive           Travel_Rarely                16
# 6  Sales Representative           Travel_Rarely                 8
#
#    EmpEducationLevel  EmpEnvironmentSatisfaction  ...  \
# 0                  3                           4  ...
# 1                  4                           4  ...
# ...

# %%
#Perfomace Rating for the employees in the sales department.
sns.countplot(x='PerformanceRating', data=Sales_Department, palette='viridis')
plt.savefig('PerformanceRating in the Sales Department')
# Out:
# <ipython-input-300-421304bf2790>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='PerformanceRating', data=Sales_Department, palette='viridis')

# %%
#Perfomance of male and female in the sales department
sns.barplot(x='PerformanceRating', y='Gender', data=Sales_Department, palette='viridis')
# Out:
# <ipython-input-301-e326a8ebfbdd>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='PerformanceRating', y='Gender', data=Sales_Department, palette='viridis')
# <Axes: xlabel='PerformanceRating', ylabel='Gender'>

# %%
#Perfomance with respect to marital status in the sales department
sns.barplot(x='PerformanceRating', y='MaritalStatus', data=Sales_Department, palette='viridis')
# Out:
# <ipython-input-302-f020126ed4a3>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='PerformanceRating', y='MaritalStatus', data=Sales_Department, palette='viridis')
# <Axes: xlabel='PerformanceRating', ylabel='MaritalStatus'>

# %%
#Perfomance with respect to job role in the sales department
print(Sales_Department.groupby('EmpJobRole').describe()['PerformanceRating'])
# Out:
#                       count      mean       std  min  25%  50%  75%  max
# EmpJobRole
# Manager                34.0  2.882353  0.728831  2.0  2.0  3.0  3.0  4.0
# Sales Executive       270.0  2.855556  0.556699  2.0  3.0  3.0  3.0  4.0
# Sales Representative   69.0  2.869565  0.450916  2.0  3.0  3.0  3.0  4.0

# %%
sns.barplot(x='PerformanceRating', y='EmpJobRole', data=Sales_Department, palette='viridis')
# Out:
# <ipython-input-304-46157229dfd5>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='PerformanceRating', y='EmpJobRole', data=Sales_Department, palette='viridis')
# <Axes: xlabel='PerformanceRating', ylabel='EmpJobRole'>

# %%
#Perfomance with respect to total work Experience in the sales department
print(Sales_Department.groupby('TotalWorkExperienceInYears').mean()['PerformanceRating'])
# Out:
# TotalWorkExperienceInYears
# 0     3.000000
# 1     3.133333
# 2     2.888889
# 3     2.666667
# 4     2.933333
# 5     2.954545
# 6     2.862069
# 7     2.937500
# 8     3.000000
# 9     2.857143
# 10    2.851852
# 11    2.777778
# 12    2.866667
# 13    2.714286
# 14    2.777778
# 15    2.750000
# 16    2.750000
# 17    2.600000
# 18    3.000000
# 19    3.000000
# 20    3.000000
# 21    2.600000
# 22    2.875000
# 23    2.857143
# 24    2.333333
# 25    2.500000
# 26    2.500000
# 27    3.000000
# 28    3.000000
# 29    3.000000
# 31    3.000000
# 32    3.000000
# 33    2.000000
# 34    4.000000
# 35    3.000000
# 36    4.000000
# 37    2.000000
# 38    3.000000
# Name: PerformanceRating, dtype: float64
# <ipython-input-305-54a5c10f03e7>:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
# ...

# %%
sns.barplot(x='PerformanceRating', y='TotalWorkExperienceInYears', data=Sales_Department, palette='viridis')
# Out:
# <ipython-input-306-64b39cd32b64>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='PerformanceRating', y='TotalWorkExperienceInYears', data=Sales_Department, palette='viridis')
# <Axes: xlabel='PerformanceRating', ylabel='TotalWorkExperienceInYears'>

# %%
#Perfomance according to employees last salary hike percentage
print(Sales_Department.groupby('EmpLastSalaryHikePercent').max()['PerformanceRating'])
# Out:
# EmpLastSalaryHikePercent
# 11    4
# 12    4
# 13    4
# 14    4
# 15    4
# 16    3
# 17    3
# 18    3
# 19    4
# 20    4
# 21    4
# 22    4
# 23    4
# 24    4
# 25    4
# Name: PerformanceRating, dtype: int64

# %%
print(Sales_Department.groupby('EmpLastSalaryHikePercent').max()['PerformanceRating'])
# Out:
# EmpLastSalaryHikePercent
# 11    4
# 12    4
# 13    4
# 14    4
# 15    4
# 16    3
# 17    3
# 18    3
# 19    4
# 20    4
# 21    4
# 22    4
# 23    4
# 24    4
# 25    4
# Name: PerformanceRating, dtype: int64

# %%
sns.barplot(x='PerformanceRating', y='EmpLastSalaryHikePercent', data=Sales_Department, palette='viridis')
# Out:
# <ipython-input-311-5f19d098f366>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='PerformanceRating', y='EmpLastSalaryHikePercent', data=Sales_Department, palette='viridis')
# <Axes: xlabel='PerformanceRating', ylabel='EmpLastSalaryHikePercent'>

# %%
#Perfomance with respect to years since last promotion
print(Sales_Department.groupby('YearsSinceLastPromotion').min()['PerformanceRating'])
# Out:
# YearsSinceLastPromotion
# 0     2
# 1     2
# 2     2
# 3     2
# 4     2
# 5     2
# 6     2
# 7     2
# 8     2
# 9     2
# 10    2
# 11    2
# 12    2
# 13    3
# 14    2
# 15    2
# Name: PerformanceRating, dtype: int64

# %%
print(Sales_Department.groupby('YearsSinceLastPromotion').max()['PerformanceRating'])
# Out:
# YearsSinceLastPromotion
# 0     4
# 1     4
# 2     4
# 3     3
# 4     3
# 5     4
# 6     4
# 7     4
# 8     3
# 9     3
# 10    2
# 11    4
# 12    3
# 13    3
# 14    2
# 15    4
# Name: PerformanceRating, dtype: int64

# %%
sns.barplot(x='PerformanceRating', y='YearsSinceLastPromotion', data=Sales_Department, palette='viridis')
# Out:
# <ipython-input-314-bb4f3f672b29>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='PerformanceRating', y='YearsSinceLastPromotion', data=Sales_Department, palette='viridis')
# <Axes: xlabel='PerformanceRating', ylabel='YearsSinceLastPromotion'>

# %%
#Perfomance with respect with the employee's environment satisfaction
print(Sales_Department.groupby('EmpEnvironmentSatisfaction').mean()['PerformanceRating'])
# Out:
# EmpEnvironmentSatisfaction
# 1    2.527027
# 2    2.505882
# 3    3.117117
# 4    3.116505
# Name: PerformanceRating, dtype: float64
# <ipython-input-315-32e73022eca6>:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   print(Sales_Department.groupby('EmpEnvironmentSatisfaction').mean()['PerformanceRating'])

# %%
sns.barplot(x='PerformanceRating', y='EmpEnvironmentSatisfaction', data=Sales_Department, palette='viridis')
# Out:
# <ipython-input-316-7fd67d5e86cb>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='PerformanceRating', y='EmpEnvironmentSatisfaction', data=Sales_Department, palette='viridis')
# <Axes: xlabel='PerformanceRating', ylabel='EmpEnvironmentSatisfaction'>

# %% [markdown]
# ### Research and Development Department

# %%
Research_Department = df[df.EmpDepartment == 'Research & Development'] # Slicing the all coloums of Sales Row
Research_Department.head()
# Out:
#      Age  Gender EducationBackground MaritalStatus           EmpDepartment  \
# 156   38    Male             Medical       Married  Research & Development
# 157   35    Male               Other      Divorced  Research & Development
# 158   31  Female       Life Sciences       Married  Research & Development
# 159   18    Male       Life Sciences        Single  Research & Development
# 160   54  Female    Technical Degree       Married  Research & Development
#
#                  EmpJobRole BusinessTravelFrequency  DistanceFromHome  \
# 156      Senior Manager R&D       Travel_Frequently                10
# 157   Laboratory Technician           Travel_Rarely                14
# 158  Manufacturing Director       Travel_Frequently                 1
# 159      Research Scientist              Non-Travel                 5
# 160      Senior Manager R&D           Travel_Rarely                17
#
#      EmpEducationLevel  EmpEnvironmentSatisfaction  ...  \
# ...

# %%
#Perfomace Rating for the employees in the Research department.
sns.countplot(x='PerformanceRating', data=Research_Department, palette='viridis')
plt.savefig('PerformanceRating in the Research Department')
# Out:
# <ipython-input-318-1bdeccb8fc09>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='PerformanceRating', data=Research_Department, palette='viridis')

# %%
#Perfomance of male and female in the Research department
sns.barplot(x='PerformanceRating', y='Gender', data=Research_Department, palette='viridis')
# Out:
# <ipython-input-319-4723d8fe3d81>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='PerformanceRating', y='Gender', data=Research_Department, palette='viridis')
# <Axes: xlabel='PerformanceRating', ylabel='Gender'>

# %%
#Perfomance with respect to marital status in the Research department
sns.barplot(x='PerformanceRating', y='MaritalStatus', data=Research_Department, palette='viridis')
# Out:
# <ipython-input-320-b4999d027fb7>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='PerformanceRating', y='MaritalStatus', data=Research_Department, palette='viridis')
# <Axes: xlabel='PerformanceRating', ylabel='MaritalStatus'>

# %%
#Perfomance with respect to job role in the Research department
print(Research_Department.groupby('EmpJobRole').describe()['PerformanceRating'])
# Out:
#                            count      mean       std  min  25%  50%   75%  max
# EmpJobRole
# Healthcare Representative   33.0  2.848485  0.565752  2.0  3.0  3.0  3.00  4.0
# Laboratory Technician       64.0  2.859375  0.530564  2.0  3.0  3.0  3.00  4.0
# Manager                      8.0  3.250000  0.462910  3.0  3.0  3.0  3.25  4.0
# Manager R&D                 94.0  2.936170  0.544938  2.0  3.0  3.0  3.00  4.0
# Manufacturing Director      33.0  2.969697  0.394085  2.0  3.0  3.0  3.00  4.0
# Research Director           19.0  2.894737  0.657836  2.0  2.5  3.0  3.00  4.0
# Research Scientist          77.0  2.961039  0.637461  2.0  3.0  3.0  3.00  4.0
# Senior Manager R&D          15.0  2.800000  0.560612  2.0  2.5  3.0  3.00  4.0

# %%
sns.barplot(x='PerformanceRating', y='EmpJobRole', data=Research_Department, palette='viridis')
# Out:
# <ipython-input-322-2288a076892a>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='PerformanceRating', y='EmpJobRole', data=Research_Department, palette='viridis')
# <Axes: xlabel='PerformanceRating', ylabel='EmpJobRole'>

# %%
#Perfomance according to total work experiences
print(Research_Department.groupby('TotalWorkExperienceInYears').mean()['PerformanceRating'])
# Out:
# TotalWorkExperienceInYears
# 0     3.250000
# 1     3.315789
# 2     2.875000
# 3     2.600000
# 4     2.705882
# 5     2.947368
# 6     2.851852
# 7     2.888889
# 8     3.166667
# 9     2.904762
# 10    2.761905
# 11    3.083333
# 12    3.000000
# 13    3.500000
# 14    2.700000
# 15    2.615385
# 16    3.000000
# 17    3.000000
# 18    2.777778
# 19    3.200000
# 20    2.727273
# 21    2.750000
# 22    3.000000
# 23    2.800000
# 24    3.000000
# 25    3.142857
# 26    2.666667
# 27    2.666667
# 28    2.666667
# 29    3.000000
# 30    3.000000
# 31    3.500000
# 32    3.666667
# 33    3.000000
# 34    3.000000
# 36    3.000000
# Name: PerformanceRating, dtype: float64
# <ipython-input-323-fceaaa15d739>:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
# ...

# %%
sns.barplot(x='PerformanceRating', y='TotalWorkExperienceInYears', data=Research_Department, palette='viridis')
# Out:
# <ipython-input-324-67c3da790bd2>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='PerformanceRating', y='TotalWorkExperienceInYears', data=Research_Department, palette='viridis')
# <Axes: xlabel='PerformanceRating', ylabel='TotalWorkExperienceInYears'>

# %%
#Perfomance according to employees last salary hike percentage
print(Research_Department.groupby('EmpLastSalaryHikePercent').describe()['PerformanceRating'])
# Out:
#                           count      mean       std  min   25%  50%  75%  max
# EmpLastSalaryHikePercent
# 11                         46.0  2.891304  0.314696  2.0  3.00  3.0  3.0  3.0
# 12                         44.0  2.704545  0.509425  2.0  2.00  3.0  3.0  4.0
# 13                         48.0  2.750000  0.437595  2.0  2.75  3.0  3.0  3.0
# 14                         55.0  2.818182  0.434226  2.0  3.00  3.0  3.0  4.0
# 15                         19.0  2.947368  0.524265  2.0  3.00  3.0  3.0  4.0
# 16                         18.0  2.833333  0.383482  2.0  3.00  3.0  3.0  3.0
# 17                         21.0  2.857143  0.358569  2.0  3.00  3.0  3.0  3.0
# 18                         19.0  2.789474  0.418854  2.0  3.00  3.0  3.0  3.0
# 19                         15.0  2.866667  0.516398  2.0  3.00  3.0  3.0  4.0
# 20                         21.0  3.238095  0.830949  2.0  3.00  3.0  4.0  4.0
# 21                          4.0  4.000000  0.000000  4.0  4.00  4.0  4.0  4.0
# ...

# %%
sns.barplot(x='PerformanceRating', y='EmpLastSalaryHikePercent', data=Research_Department, palette='viridis')
# Out:
# <ipython-input-326-7a8ebb3f3db8>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='PerformanceRating', y='EmpLastSalaryHikePercent', data=Research_Department, palette='viridis')
# <Axes: xlabel='PerformanceRating', ylabel='EmpLastSalaryHikePercent'>

# %%
#Perfomance with respect to years since last promotion
print(Research_Department.groupby('YearsSinceLastPromotion').min()['PerformanceRating'])
# Out:
# YearsSinceLastPromotion
# 0     2
# 1     2
# 2     2
# 3     2
# 4     2
# 5     2
# 6     2
# 7     2
# 8     2
# 9     2
# 10    3
# 11    2
# 12    2
# 13    3
# 14    3
# 15    3
# Name: PerformanceRating, dtype: int64

# %%
print(Research_Department.groupby('YearsSinceLastPromotion').max()['PerformanceRating'])
# Out:
# YearsSinceLastPromotion
# 0     4
# 1     4
# 2     4
# 3     4
# 4     4
# 5     3
# 6     4
# 7     4
# 8     3
# 9     3
# 10    3
# 11    3
# 12    3
# 13    4
# 14    4
# 15    3
# Name: PerformanceRating, dtype: int64

# %%
sns.barplot(x='PerformanceRating', y='YearsSinceLastPromotion', data=Research_Department, palette='viridis')
# Out:
# <ipython-input-329-8f427fde8d96>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='PerformanceRating', y='YearsSinceLastPromotion', data=Research_Department, palette='viridis')
# <Axes: xlabel='PerformanceRating', ylabel='YearsSinceLastPromotion'>

# %%
#Perfomance with respect with the employee's environment satisfaction
print(Research_Department.groupby('EmpEnvironmentSatisfaction').mean()['PerformanceRating'])
# Out:
# EmpEnvironmentSatisfaction
# 1    2.575758
# 2    2.491803
# 3    3.150000
# 4    3.146552
# Name: PerformanceRating, dtype: float64
# <ipython-input-330-e63b9e4cfdba>:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   print(Research_Department.groupby('EmpEnvironmentSatisfaction').mean()['PerformanceRating'])

# %%
sns.barplot(x='PerformanceRating', y='EmpEnvironmentSatisfaction', data=Research_Department, palette='viridis')
# Out:
# <ipython-input-331-9f0f24e68693>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='PerformanceRating', y='EmpEnvironmentSatisfaction', data=Research_Department, palette='viridis')
# <Axes: xlabel='PerformanceRating', ylabel='EmpEnvironmentSatisfaction'>

# %% [markdown]
# ### Human Resources Department

# %%
HR_Department = df[df.EmpDepartment == 'Human Resources'] # Slicing the all coloums of Sales Row
HR_Department.head()
# Out:
#     Age  Gender EducationBackground MaritalStatus    EmpDepartment  \
# 3    41    Male     Human Resources      Divorced  Human Resources
# 16   39  Female     Human Resources       Married  Human Resources
# 58   36    Male     Human Resources       Married  Human Resources
# 81   28    Male             Medical      Divorced  Human Resources
# 85   36    Male       Life Sciences       Married  Human Resources
#
#          EmpJobRole BusinessTravelFrequency  DistanceFromHome  \
# 3           Manager           Travel_Rarely                10
# 16  Human Resources           Travel_Rarely                 3
# 58  Human Resources           Travel_Rarely                13
# 81  Human Resources           Travel_Rarely                 8
# 85  Human Resources           Travel_Rarely                 8
#
#     EmpEducationLevel  EmpEnvironmentSatisfaction  ...  \
# 3                   4                           2  ...
# 16                  3                           3  ...
# ...

# %%
#Perfomace Rating for the employees
sns.countplot(x='PerformanceRating', data=HR_Department, palette='viridis')
plt.savefig('PerformanceRating in the Human Resources Department')
# Out:
# <ipython-input-333-d391baa72ca5>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='PerformanceRating', data=HR_Department, palette='viridis')

# %%
#Perfomance of male and female
sns.barplot(x='PerformanceRating', y='Gender', data=HR_Department, palette='viridis')
# Out:
# <ipython-input-334-fddd6e530f1c>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='PerformanceRating', y='Gender', data=HR_Department, palette='viridis')
# <Axes: xlabel='PerformanceRating', ylabel='Gender'>

# %%
#Perfomance with respect to job role
print(HR_Department.groupby('EmpJobRole').describe()['PerformanceRating'])
# Out:
#                  count      mean       std  min  25%  50%  75%  max
# EmpJobRole
# Human Resources   45.0  2.911111  0.556867  2.0  3.0  3.0  3.0  4.0
# Manager            9.0  3.000000  0.500000  2.0  3.0  3.0  3.0  4.0

# %%
sns.barplot(x='PerformanceRating', y='EmpJobRole', data=HR_Department, palette='viridis')
# Out:
# <ipython-input-336-2ccc9e0bac9a>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='PerformanceRating', y='EmpJobRole', data=HR_Department, palette='viridis')
# <Axes: xlabel='PerformanceRating', ylabel='EmpJobRole'>

# %%
#Perfomance according to total work experiences
print(HR_Department.groupby('TotalWorkExperienceInYears').mean()['PerformanceRating'])
# Out:
# TotalWorkExperienceInYears
# 1     3.000000
# 2     2.500000
# 3     2.500000
# 4     3.000000
# 5     2.000000
# 6     2.833333
# 7     3.000000
# 8     3.250000
# 9     3.000000
# 10    3.125000
# 11    3.000000
# 12    3.000000
# 13    2.500000
# 14    3.000000
# 16    3.000000
# 19    3.000000
# 21    3.500000
# 23    3.000000
# 24    2.000000
# 27    3.000000
# 32    2.000000
# 33    3.000000
# 35    3.000000
# 36    3.000000
# Name: PerformanceRating, dtype: float64
# <ipython-input-337-c26bb40a59ab>:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   print(HR_Department.groupby('TotalWorkExperienceInYears').mean()['PerformanceRating'])

# %%
sns.barplot(x='PerformanceRating', y='TotalWorkExperienceInYears', data=HR_Department, palette='viridis')
# Out:
# <ipython-input-338-989bb774c6ef>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='PerformanceRating', y='TotalWorkExperienceInYears', data=HR_Department, palette='viridis')
# <Axes: xlabel='PerformanceRating', ylabel='TotalWorkExperienceInYears'>

# %%
#Perfomance according to employees last salary hike percentage
print(HR_Department.groupby('EmpLastSalaryHikePercent').describe()['PerformanceRating'])
# Out:
#                           count      mean       std  min   25%  50%   75%  max
# EmpLastSalaryHikePercent
# 11                         13.0  2.923077  0.277350  2.0  3.00  3.0  3.00  3.0
# 12                          5.0  2.800000  0.447214  2.0  3.00  3.0  3.00  3.0
# 13                          7.0  2.571429  0.534522  2.0  2.00  3.0  3.00  3.0
# 14                          5.0  2.600000  0.547723  2.0  2.00  3.0  3.00  3.0
# 15                          6.0  2.833333  0.408248  2.0  3.00  3.0  3.00  3.0
# 16                          3.0  3.333333  0.577350  3.0  3.00  3.0  3.50  4.0
# 17                          3.0  2.333333  0.577350  2.0  2.00  2.0  2.50  3.0
# 18                          3.0  3.000000  0.000000  3.0  3.00  3.0  3.00  3.0
# 19                          2.0  3.000000  0.000000  3.0  3.00  3.0  3.00  3.0
# 21                          4.0  3.750000  0.500000  3.0  3.75  4.0  4.00  4.0
# 22                          2.0  3.500000  0.707107  3.0  3.25  3.5  3.75  4.0
# ...

# %%
sns.barplot(x='PerformanceRating', y='EmpLastSalaryHikePercent', data=HR_Department, palette='viridis')
# Out:
# <ipython-input-340-3570c65a31c0>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='PerformanceRating', y='EmpLastSalaryHikePercent', data=HR_Department, palette='viridis')
# <Axes: xlabel='PerformanceRating', ylabel='EmpLastSalaryHikePercent'>

# %%
#Perfomance with respect to years since last promotion
print(HR_Department.groupby('YearsSinceLastPromotion').min()['PerformanceRating'])
# Out:
# YearsSinceLastPromotion
# 0     3
# 1     2
# 2     2
# 3     2
# 4     3
# 5     3
# 7     3
# 10    2
# 12    3
# Name: PerformanceRating, dtype: int64

# %%
print(HR_Department.groupby('YearsSinceLastPromotion').max()['PerformanceRating'])
# Out:
# YearsSinceLastPromotion
# 0     4
# 1     3
# 2     3
# 3     3
# 4     3
# 5     4
# 7     4
# 10    2
# 12    3
# Name: PerformanceRating, dtype: int64

# %%
sns.barplot(x='PerformanceRating', y='YearsSinceLastPromotion', data=HR_Department, palette='viridis')
# Out:
# <ipython-input-343-6aaad6464ae6>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='PerformanceRating', y='YearsSinceLastPromotion', data=HR_Department, palette='viridis')
# <Axes: xlabel='PerformanceRating', ylabel='YearsSinceLastPromotion'>

# %%
#Perfomance with respect with the employee's environment satisfaction
print(HR_Department.groupby('EmpEnvironmentSatisfaction').mean()['PerformanceRating'])
# Out:
# EmpEnvironmentSatisfaction
# 1    2.500000
# 2    2.727273
# 3    3.136364
# 4    3.090909
# Name: PerformanceRating, dtype: float64
# <ipython-input-344-4f508dd3a15a>:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   print(HR_Department.groupby('EmpEnvironmentSatisfaction').mean()['PerformanceRating'])

# %%
sns.barplot(x='PerformanceRating', y='EmpEnvironmentSatisfaction', data=HR_Department, palette='viridis')
# Out:
# <ipython-input-345-c26391311b9a>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='PerformanceRating', y='EmpEnvironmentSatisfaction', data=HR_Department, palette='viridis')
# <Axes: xlabel='PerformanceRating', ylabel='EmpEnvironmentSatisfaction'>

# %% [markdown]
# ### Development Department

# %%
Development_Department = df[df.EmpDepartment == 'Development']
Development_Department.head()
# Out:
#     Age  Gender EducationBackground MaritalStatus EmpDepartment EmpJobRole  \
# 5    27    Male       Life Sciences      Divorced   Development  Developer
# 7    28  Female       Life Sciences        Single   Development  Developer
# 8    36  Female       Life Sciences       Married   Development  Developer
# 9    38  Female       Life Sciences        Single   Development  Developer
# 10   44    Male             Medical        Single   Development  Developer
#
#    BusinessTravelFrequency  DistanceFromHome  EmpEducationLevel  \
# 5        Travel_Frequently                10                  2
# 7            Travel_Rarely                 1                  2
# 8               Non-Travel                 8                  3
# 9            Travel_Rarely                 1                  3
# 10              Non-Travel                24                  3
#
#     EmpEnvironmentSatisfaction  ...  EmpRelationshipSatisfaction  \
# ...

# %%
#Perfomace Rating for the employees
sns.countplot(x='PerformanceRating', data=Development_Department, palette='viridis')
plt.savefig('PerformanceRating in the Development Department')
# Out:
# <ipython-input-347-7c7290629988>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='PerformanceRating', data=Development_Department, palette='viridis')

# %%
#Perfomance of male and female
sns.barplot(x='PerformanceRating', y='Gender', data=Development_Department, palette='viridis')
# Out:
# <ipython-input-348-faf6fdee155b>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='PerformanceRating', y='Gender', data=Development_Department, palette='viridis')
# <Axes: xlabel='PerformanceRating', ylabel='Gender'>

# %%
#Perfomance with respect to job role
print(Development_Department.groupby('EmpJobRole').describe()['PerformanceRating'])
# Out:
#                      count      mean       std  min  25%  50%  75%  max
# EmpJobRole
# Business Analyst      16.0  3.187500  0.403113  3.0  3.0  3.0  3.0  4.0
# Delivery Manager      12.0  3.000000  0.000000  3.0  3.0  3.0  3.0  3.0
# Developer            236.0  3.105932  0.382332  2.0  3.0  3.0  3.0  4.0
# Senior Developer      52.0  3.000000  0.485071  2.0  3.0  3.0  3.0  4.0
# Technical Architect    7.0  3.000000  0.000000  3.0  3.0  3.0  3.0  3.0
# Technical Lead        38.0  3.078947  0.358795  2.0  3.0  3.0  3.0  4.0

# %%
sns.barplot(x='PerformanceRating', y='EmpJobRole', data=Development_Department, palette='viridis')
# Out:
# <ipython-input-350-13a91764ff47>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='PerformanceRating', y='EmpJobRole', data=Development_Department, palette='viridis')
# <Axes: xlabel='PerformanceRating', ylabel='EmpJobRole'>

# %%
#Perfomance according to total work experiences
print(Development_Department.groupby('TotalWorkExperienceInYears').mean()['PerformanceRating'])
# Out:
# TotalWorkExperienceInYears
# 0     3.000000
# 1     3.166667
# 2     3.000000
# 3     3.181818
# 4     3.000000
# 5     3.160000
# 6     3.000000
# 7     3.200000
# 8     3.148148
# 9     3.190476
# 10    3.042553
# 11    3.250000
# 12    3.333333
# 13    3.000000
# 14    3.000000
# 15    2.714286
# 16    3.166667
# 17    3.076923
# 18    3.200000
# 19    3.125000
# 20    3.285714
# 21    2.916667
# 22    3.166667
# 23    3.000000
# 24    3.000000
# 25    2.666667
# 26    3.000000
# 28    2.600000
# 29    3.000000
# 30    3.000000
# 31    3.000000
# 32    4.000000
# 33    3.000000
# 34    3.000000
# 37    3.000000
# 40    3.000000
# Name: PerformanceRating, dtype: float64
# <ipython-input-351-a3bd9ff864df>:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
# ...

# %%
#Perfomance according to employees last salary hike percentage
print(Development_Department.groupby('EmpLastSalaryHikePercent').describe()['PerformanceRating'])
# Out:
#                           count      mean       std  min  25%  50%  75%  max
# EmpLastSalaryHikePercent
# 11                         50.0  2.920000  0.274048  2.0  3.0  3.0  3.0  3.0
# 12                         49.0  2.897959  0.305839  2.0  3.0  3.0  3.0  3.0
# 13                         57.0  3.017544  0.132453  3.0  3.0  3.0  3.0  4.0
# 14                         44.0  2.954545  0.210707  2.0  3.0  3.0  3.0  3.0
# 15                         25.0  3.040000  0.200000  3.0  3.0  3.0  3.0  4.0
# 16                         20.0  3.000000  0.324443  2.0  3.0  3.0  3.0  4.0
# 17                         20.0  3.100000  0.447214  2.0  3.0  3.0  3.0  4.0
# 18                         24.0  3.000000  0.000000  3.0  3.0  3.0  3.0  3.0
# 19                         16.0  3.000000  0.000000  3.0  3.0  3.0  3.0  3.0
# 20                         15.0  3.733333  0.457738  3.0  3.5  4.0  4.0  4.0
# 21                         10.0  3.800000  0.421637  3.0  4.0  4.0  4.0  4.0
# ...

# %%
sns.barplot(x='PerformanceRating', y='EmpLastSalaryHikePercent', data=Development_Department, palette='viridis')
# Out:
# <ipython-input-353-d359bea8233c>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='PerformanceRating', y='EmpLastSalaryHikePercent', data=Development_Department, palette='viridis')
# <Axes: xlabel='PerformanceRating', ylabel='EmpLastSalaryHikePercent'>

# %%
#Perfomance with respect to years since last promotion
print(Development_Department.groupby('YearsSinceLastPromotion').min()['PerformanceRating'])
# Out:
# YearsSinceLastPromotion
# 0     3
# 1     2
# 2     2
# 3     2
# 4     2
# 5     3
# 6     3
# 7     2
# 8     2
# 9     3
# 10    3
# 11    3
# 12    3
# 13    3
# 14    3
# 15    3
# Name: PerformanceRating, dtype: int64

# %%
print(Development_Department.groupby('YearsSinceLastPromotion').max()['PerformanceRating'])
# Out:
# YearsSinceLastPromotion
# 0     4
# 1     4
# 2     4
# 3     4
# 4     3
# 5     4
# 6     3
# 7     3
# 8     3
# 9     3
# 10    3
# 11    4
# 12    3
# 13    3
# 14    3
# 15    3
# Name: PerformanceRating, dtype: int64

# %%
sns.barplot(x='PerformanceRating', y='YearsSinceLastPromotion', data=Development_Department, palette='viridis')
# Out:
# <ipython-input-356-a144c913451e>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='PerformanceRating', y='YearsSinceLastPromotion', data=Development_Department, palette='viridis')
# <Axes: xlabel='PerformanceRating', ylabel='YearsSinceLastPromotion'>

# %%
#Perfomance with respect with the employee's environment satisfaction
print(Development_Department.groupby('EmpEnvironmentSatisfaction').mean()['PerformanceRating'])
# Out:
# EmpEnvironmentSatisfaction
# 1    2.971831
# 2    3.000000
# 3    3.165217
# 4    3.132075
# Name: PerformanceRating, dtype: float64
# <ipython-input-357-ccf73f065a40>:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   print(Development_Department.groupby('EmpEnvironmentSatisfaction').mean()['PerformanceRating'])

# %%
sns.barplot(x='PerformanceRating', y='EmpEnvironmentSatisfaction', data=Development_Department, palette='viridis')
# Out:
# <ipython-input-358-90fd3f3e24df>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='PerformanceRating', y='EmpEnvironmentSatisfaction', data=Development_Department, palette='viridis')
# <Axes: xlabel='PerformanceRating', ylabel='EmpEnvironmentSatisfaction'>

# %% [markdown]
# ### Data Science Department

# %%
DataScience_Department = df[df.EmpDepartment == 'Data Science']
DataScience_Department.head()
# Out:
#      Age  Gender EducationBackground MaritalStatus EmpDepartment  \
# 89    49  Female    Technical Degree       Married  Data Science
# 107   21  Female               Other        Single  Data Science
# 108   36    Male       Life Sciences       Married  Data Science
# 120   48    Male             Medical       Married  Data Science
# 942   51    Male       Life Sciences       Married  Data Science
#
#          EmpJobRole BusinessTravelFrequency  DistanceFromHome  \
# 89   Data Scientist           Travel_Rarely                 1
# 107  Data Scientist           Travel_Rarely                18
# 108  Data Scientist           Travel_Rarely                14
# 120  Data Scientist           Travel_Rarely                20
# 942  Data Scientist           Travel_Rarely                 8
#
#      EmpEducationLevel  EmpEnvironmentSatisfaction  ...  \
# 89                   3                           3  ...
# 107                  1                           4  ...
# ...

# %%
#Perfomace Rating for the employees in the sales department.
sns.countplot(x='PerformanceRating', data= DataScience_Department, palette='viridis')
plt.savefig('PerformanceRating in the Data Science Department')
# Out:
# <ipython-input-360-884215ae1217>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='PerformanceRating', data= DataScience_Department, palette='viridis')

# %%
#Perfomance of male and female in the Research department
sns.barplot(x='PerformanceRating', y='Gender', data=DataScience_Department, palette='viridis')
# Out:
# <ipython-input-361-15a37974caff>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='PerformanceRating', y='Gender', data=DataScience_Department, palette='viridis')
# <Axes: xlabel='PerformanceRating', ylabel='Gender'>

# %%
#Perfomance with respect to job role in the Research department
print(DataScience_Department.groupby('EmpJobRole').describe()['PerformanceRating'])
# Out:
#                 count  mean       std  min  25%  50%  75%  max
# EmpJobRole
# Data Scientist   20.0  3.05  0.394034  2.0  3.0  3.0  3.0  4.0

# %%
sns.barplot(x='PerformanceRating', y='EmpJobRole', data=DataScience_Department, palette='viridis')
# Out:
# <ipython-input-363-2edf939c0eee>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='PerformanceRating', y='EmpJobRole', data=DataScience_Department, palette='viridis')
# <Axes: xlabel='PerformanceRating', ylabel='EmpJobRole'>

# %%
#Perfomance according to total work experiences
print(DataScience_Department.groupby('TotalWorkExperienceInYears').mean()['PerformanceRating'])
# Out:
# TotalWorkExperienceInYears
# 1     3.5
# 5     3.0
# 6     3.0
# 7     3.0
# 8     3.0
# 9     3.0
# 10    4.0
# 13    3.0
# 16    3.0
# 17    3.0
# 18    3.0
# 19    3.0
# 21    3.0
# 22    2.0
# 31    3.0
# Name: PerformanceRating, dtype: float64
# <ipython-input-364-ebe07a05e3e3>:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   print(DataScience_Department.groupby('TotalWorkExperienceInYears').mean()['PerformanceRating'])

# %%
#Perfomance according to employees last salary hike percentage
print(DataScience_Department.groupby('EmpLastSalaryHikePercent').describe()['PerformanceRating'])
# Out:
#                           count  mean  std  min   25%  50%  75%  max
# EmpLastSalaryHikePercent
# 11                          2.0  3.00  0.0  3.0  3.00  3.0  3.0  3.0
# 13                          2.0  3.00  0.0  3.0  3.00  3.0  3.0  3.0
# 14                          3.0  3.00  0.0  3.0  3.00  3.0  3.0  3.0
# 16                          3.0  3.00  0.0  3.0  3.00  3.0  3.0  3.0
# 17                          3.0  3.00  0.0  3.0  3.00  3.0  3.0  3.0
# 19                          4.0  2.75  0.5  2.0  2.75  3.0  3.0  3.0
# 20                          1.0  3.00  NaN  3.0  3.00  3.0  3.0  3.0
# 21                          1.0  4.00  NaN  4.0  4.00  4.0  4.0  4.0
# 23                          1.0  4.00  NaN  4.0  4.00  4.0  4.0  4.0

# %%
sns.barplot(x='PerformanceRating', y='EmpLastSalaryHikePercent', data=DataScience_Department, palette='viridis')
# Out:
# <ipython-input-366-0ab3888dee14>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='PerformanceRating', y='EmpLastSalaryHikePercent', data=DataScience_Department, palette='viridis')
# <Axes: xlabel='PerformanceRating', ylabel='EmpLastSalaryHikePercent'>

# %%
#Perfomance with respect to years since last promotion
print(DataScience_Department.groupby('YearsSinceLastPromotion').min()['PerformanceRating'])
# Out:
# YearsSinceLastPromotion
# 0    3
# 1    3
# 2    3
# 3    2
# 4    3
# 7    3
# Name: PerformanceRating, dtype: int64

# %%
print(DataScience_Department.groupby('YearsSinceLastPromotion').max()['PerformanceRating'])
# Out:
# YearsSinceLastPromotion
# 0    4
# 1    3
# 2    3
# 3    2
# 4    3
# 7    4
# Name: PerformanceRating, dtype: int64

# %%
sns.barplot(x='PerformanceRating', y='YearsSinceLastPromotion', data=DataScience_Department, palette='viridis')
# Out:
# <ipython-input-369-af12876d131b>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='PerformanceRating', y='YearsSinceLastPromotion', data=DataScience_Department, palette='viridis')
# <Axes: xlabel='PerformanceRating', ylabel='YearsSinceLastPromotion'>

# %%
#Perfomance with respect with the employee's environment satisfaction
print(DataScience_Department.groupby('EmpEnvironmentSatisfaction').mean()['PerformanceRating'])
# Out:
# EmpEnvironmentSatisfaction
# 1    2.500000
# 2    3.250000
# 3    3.000000
# 4    3.142857
# Name: PerformanceRating, dtype: float64
# <ipython-input-370-b62ff469a189>:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   print(DataScience_Department.groupby('EmpEnvironmentSatisfaction').mean()['PerformanceRating'])

# %%
sns.barplot(x='PerformanceRating', y='EmpEnvironmentSatisfaction', data=DataScience_Department, palette='viridis')
# Out:
# <ipython-input-371-2069d3f434a6>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='PerformanceRating', y='EmpEnvironmentSatisfaction', data=DataScience_Department, palette='viridis')
# <Axes: xlabel='PerformanceRating', ylabel='EmpEnvironmentSatisfaction'>

# %% [markdown]
# ### Finance Department

# %%
Finance_Department = df[df.EmpDepartment == 'Finance']
Finance_Department.head()
# Out:
#      Age Gender EducationBackground MaritalStatus EmpDepartment  \
# 482   29   Male       Life Sciences      Divorced       Finance
# 484   23   Male    Technical Degree       Married       Finance
# 485   35   Male       Life Sciences       Married       Finance
# 486   34   Male    Technical Degree       Married       Finance
# 487   43   Male    Technical Degree      Divorced       Finance
#
#           EmpJobRole BusinessTravelFrequency  DistanceFromHome  \
# 482  Finance Manager       Travel_Frequently                 2
# 484  Finance Manager           Travel_Rarely                10
# 485  Finance Manager           Travel_Rarely                28
# 486  Finance Manager       Travel_Frequently                10
# 487  Finance Manager           Travel_Rarely                27
#
#      EmpEducationLevel  EmpEnvironmentSatisfaction  ...  \
# 482                  1                           1  ...
# 484                  3                           4  ...
# ...

# %%
#Perfomace Rating for the employees
sns.countplot(x='PerformanceRating', data= Finance_Department, palette='viridis')
plt.savefig('PerformanceRating in the Finance Department')
# Out:
# <ipython-input-373-46102966dfe2>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='PerformanceRating', data= Finance_Department, palette='viridis')

# %%
#Perfomance of male and female
sns.barplot(x='PerformanceRating', y='Gender', data=Finance_Department, palette='viridis')
# Out:
# <ipython-input-374-c8c283320fe0>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='PerformanceRating', y='Gender', data=Finance_Department, palette='viridis')
# <Axes: xlabel='PerformanceRating', ylabel='Gender'>

# %%
#Perfomance according to total work experiences
print(Finance_Department.groupby('TotalWorkExperienceInYears').mean()['PerformanceRating'])
# Out:
# TotalWorkExperienceInYears
# 1     3.000000
# 3     3.000000
# 4     2.666667
# 5     3.000000
# 6     2.500000
# 7     3.333333
# 8     2.500000
# 9     3.000000
# 10    2.714286
# 11    2.666667
# 13    4.000000
# 14    4.000000
# 15    2.500000
# 16    2.000000
# 17    3.000000
# 18    3.000000
# 19    3.000000
# 23    2.000000
# 27    2.000000
# 30    3.000000
# 32    2.000000
# 36    2.000000
# Name: PerformanceRating, dtype: float64
# <ipython-input-375-5fee0a28f2f5>:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   print(Finance_Department.groupby('TotalWorkExperienceInYears').mean()['PerformanceRating'])

# %%
#Perfomance according to employees last salary hike percentage
print(Finance_Department.groupby('EmpLastSalaryHikePercent').describe()['PerformanceRating'])
# Out:
#                           count      mean       std  min   25%  50%   75%  max
# EmpLastSalaryHikePercent
# 11                          5.0  2.400000  0.547723  2.0  2.00  2.0  3.00  3.0
# 12                          7.0  2.714286  0.487950  2.0  2.50  3.0  3.00  3.0
# 13                          5.0  2.600000  0.547723  2.0  2.00  3.0  3.00  3.0
# 14                          6.0  2.666667  0.516398  2.0  2.25  3.0  3.00  3.0
# 15                          6.0  2.666667  0.516398  2.0  2.25  3.0  3.00  3.0
# 16                          3.0  2.666667  0.577350  2.0  2.50  3.0  3.00  3.0
# 17                          6.0  2.833333  0.408248  2.0  3.00  3.0  3.00  3.0
# 18                          1.0  3.000000       NaN  3.0  3.00  3.0  3.00  3.0
# 19                          4.0  2.750000  0.500000  2.0  2.75  3.0  3.00  3.0
# 20                          2.0  4.000000  0.000000  4.0  4.00  4.0  4.00  4.0
# 21                          2.0  3.500000  0.707107  3.0  3.25  3.5  3.75  4.0
# ...

# %%
sns.barplot(x='PerformanceRating', y='EmpLastSalaryHikePercent', data=Finance_Department, palette='viridis')
# Out:
# <ipython-input-377-7b4d59b86279>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='PerformanceRating', y='EmpLastSalaryHikePercent', data=Finance_Department, palette='viridis')
# <Axes: xlabel='PerformanceRating', ylabel='EmpLastSalaryHikePercent'>

# %%
#Perfomance with respect to years since last promotion
print(Finance_Department.groupby('YearsSinceLastPromotion').min()['PerformanceRating'])
# Out:
# YearsSinceLastPromotion
# 0     3
# 1     2
# 2     3
# 3     2
# 4     2
# 5     4
# 6     2
# 7     2
# 12    2
# Name: PerformanceRating, dtype: int64

# %%
print(Finance_Department.groupby('YearsSinceLastPromotion').max()['PerformanceRating'])
# Out:
# YearsSinceLastPromotion
# 0     4
# 1     4
# 2     3
# 3     3
# 4     2
# 5     4
# 6     4
# 7     3
# 12    2
# Name: PerformanceRating, dtype: int64

# %%
#Perfomance with respect with the employee's environment satisfaction
print(Finance_Department.groupby('EmpEnvironmentSatisfaction').mean()['PerformanceRating'])
# Out:
# EmpEnvironmentSatisfaction
# 1    2.142857
# 2    2.250000
# 3    3.083333
# 4    3.166667
# Name: PerformanceRating, dtype: float64
# <ipython-input-380-3b8bb59cb55f>:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   print(Finance_Department.groupby('EmpEnvironmentSatisfaction').mean()['PerformanceRating'])

# %%
sns.barplot(x='PerformanceRating', y='EmpEnvironmentSatisfaction', data=Finance_Department, palette='viridis')
# Out:
# <ipython-input-381-84cbc6df25bf>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='PerformanceRating', y='EmpEnvironmentSatisfaction', data=Finance_Department, palette='viridis')
# <Axes: xlabel='PerformanceRating', ylabel='EmpEnvironmentSatisfaction'>

# %% [markdown]
# ### Coorelation Analysis

# %%
corr = df.corr()
fig, ax = plt.subplots(figsize=(20,30))
sns.heatmap(corr, annot=True, ax=ax, cmap = "viridis")
plt.savefig('Coorelation of Columns')
# Out:
# <ipython-input-382-c3e89908f805>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = df.corr()

# %%
corr = df.corr()
corr['PerformanceRating'].sort_values(ascending = False)
# Out:
# <ipython-input-383-00cad6ac7a10>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = df.corr()
# PerformanceRating               1.000000
# EmpEnvironmentSatisfaction      0.395561
# EmpLastSalaryHikePercent        0.333722
# EmpWorkLifeBalance              0.124429
# NumCompaniesWorked              0.020980
# EmpEducationLevel               0.020529
# EmpJobSatisfaction              0.000606
# TrainingTimesLastYear          -0.005443
# EmpJobInvolvement              -0.010539
# EmpRelationshipSatisfaction    -0.019502
# Age                            -0.040164
# EmpHourlyRate                  -0.043116
# DistanceFromHome               -0.046142
# TotalWorkExperienceInYears     -0.068141
# EmpJobLevel                    -0.076632
# ExperienceYearsAtThisCompany   -0.111645
# ...

# %% [markdown]
# ####OBSERVATIONS
#
# Data Science and Development departments have the highest mean perfomance rating of 3 while the rest of the departments have a mean perfomance rating of 2.
# In all departments those with a high salary percentage have a high perfomance rating.
# Also high level of environment satisfaction translates to high perfomance rating..
#
# **Sales Department**
#
# The Performace rating level 3 (High) is more in the sales department.
#
# The male employees in the sales departmnent have a performance rating that is little bit higher compared to female.
#
# Divorced have a rating of 3 while the married and single have a less rating.
#
# The total work experience does not count the performance rating.
#
# **Human Resources Department**
#
# Most employees employees have a level 3 performance.
#
# The older people are performing low in this department.
#
# The female employees in HR department doing really well in their performance.
# The total work experience does matter to performance in this department.
#
# **Development Department**
#
#  The largest number of employees are level 3 performers.
#
#  Managers have the highest rating of 3
#
#  The gender-based performance is nearly same for both.
#
# **Data Science Department**
#
# The highest average of level 3 performance is in data science department.
#
# Businees Analyst in the department have highest rating
#
# The overall performance is higher compared to all departments.
#
# Male employees are doing good in this department.
#
# **Research & Development Department**
#
# The largest number of employees are level 3 performers.
#
# Managers have the highest rating while Health Care Rep have the lowest rating.
#
# The gender-based performance is nearly same for both.
#
# The marital status does not matter in this department.
#
# **Finance Department**
#
# Male employees have a higher rating than their female counterparts.
# A majority of the employees have a rating of 3.
#
# Most employees have a rating of 3.
#
#
# ### COORELATION ANALYSIS
#
# The Total years of experience and job level are having the higher correlation when comparing to all features.
#
# Experience years at this company and years with the current manager has the second higher relation between these features.
#
# Experience years at this company and experience in the current role makes the sense of correlation.
#
# People who have more experience with the company has the more probability to get the promotion from the correlation between them.
#
# In this plot, the age has the important role in the total number of work experience of an employee where it is a universal truth.

# %% [markdown]
# #MODEL BUILDING
# *   Here the categorical column are encoded using Label Encoding, then seperate Features and Target
# *   Splitting the data: Perfomance Rating will be the target
# *   Scaling the data
# *   Decision Tree Classifier
# *   Random Forest Classifier

# %%
#Encoding the categorical columns
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
for x in df:
    if df[x].dtypes=='object':
        df[x] = le.fit_transform(df[x])

# %%
#Separating Features and Target
X = df.drop(columns=['PerformanceRating','Age','Gender','MaritalStatus'])
Y = df['PerformanceRating']

# %%
# Splitting the data using train data & testing data

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, stratify=Y, random_state=2)

# %%
print(X.shape, X_train.shape, X_test.shape)
# Out:
# (1200, 23) (960, 23) (240, 23)

# %%
#Scaling the Data
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
scaler.fit(X_train)
x_train=scaler.transform(X_train)
x_test=scaler.transform(X_test)

# %% [markdown]
# ##Decision Tree Classifier

# %%
# import DecisionTreeClassifier
from sklearn.tree import DecisionTreeClassifier

# %%
# instantiate the DecisionTreeClassifier model with criterion gini index
clf_gini = DecisionTreeClassifier(criterion='gini', max_depth=3, random_state=0)
# fit the model
clf_gini.fit(X_train, Y_train)
# Out:
# DecisionTreeClassifier(max_depth=3, random_state=0)

# %%
#Predict the Test set results with criterion gini index
Y_pred_gini = clf_gini.predict(X_test)

# %%
#Check accuracy score with criterion gini index
print('Model accuracy score with criterion gini index: {0:0.4f}'. format(accuracy_score(Y_test, Y_pred_gini)))
# Out:
# Model accuracy score with criterion gini index: 0.8708

# %% [markdown]
# The model score is 0.8708 with the decision tree classifier with criterion gini index

# %%
#Check for Overffitting and Underfitting
print('Training set score: {:.4f}'.format(clf_gini.score(X_train, Y_train)))
print('Test set score: {:.4f}'.format(clf_gini.score(X_test, Y_test)))
# Out:
# Training set score: 0.8906
# Test set score: 0.8708

# %% [markdown]
# The model is neither under or overfitted.

# %%
#Visualizing Decision Tree
plt.figure(figsize=(12,8))
from sklearn import tree
tree.plot_tree(clf_gini.fit(X_train, Y_train));

# %% [markdown]
# ##Random Forest Classifier with parameter n_estimators=100

# %%
# import Random Forest classifier
from sklearn.ensemble import RandomForestClassifier
# instantiate the classifier with n_estimators = 100
rfc_100 = RandomForestClassifier(n_estimators=100, random_state=0)
# fit the model to the training set
rfc_100.fit(X_train, Y_train)
# Predict on the test set results
y_pred_100 = rfc_100.predict(X_test)
# Check accuracy score
print('Model accuracy score with 100 decision-trees : {0:0.4f}'. format(accuracy_score(Y_test, y_pred_100)))
# Out:
# Model accuracy score with 100 decision-trees : 0.9167

# %% [markdown]
# The model accuracy score with random forest classifier is 0.9167.

# %% [markdown]
# ###FIND THE IMPORTANT FEATURES

# %%
# create the classifier with n_estimators = 10
clf = RandomForestClassifier(n_estimators=100, random_state=0)
# fit the model to the training set
clf.fit(X_train, Y_train)
# Out:
# RandomForestClassifier(random_state=0)

# %%
# view the feature scores
feature_scores = pd.Series(clf.feature_importances_, index=X_train.columns).sort_values(ascending=False)
feature_scores
# Out:
# EmpLastSalaryHikePercent        0.206816
# EmpEnvironmentSatisfaction      0.191374
# YearsSinceLastPromotion         0.103522
# EmpHourlyRate                   0.044770
# EmpJobRole                      0.042299
# ExperienceYearsInCurrentRole    0.042269
# EmpDepartment                   0.040940
# ExperienceYearsAtThisCompany    0.036723
# TotalWorkExperienceInYears      0.033918
# DistanceFromHome                0.032447
# YearsWithCurrManager            0.030116
# EmpWorkLifeBalance              0.027923
# NumCompaniesWorked              0.021329
# TrainingTimesLastYear           0.021100
# EmpEducationLevel               0.018010
# EmpJobInvolvement               0.017255
# EducationBackground             0.016714
# EmpRelationshipSatisfaction     0.016694
# EmpJobSatisfaction              0.016577
# EmpJobLevel                     0.015620
# BusinessTravelFrequency         0.010197
# Attrition                       0.006733
# OverTime                        0.006653
# ...

# %%
# Select the top 10 features
top_10_features = feature_scores.nlargest(10)

# Create a bar plot
sns.barplot(x=top_10_features, y=top_10_features.index)

# Add labels to the graph
plt.xlabel('Feature Importance Score')
plt.ylabel('Features')

# Add title to the graph
plt.title("Visualizing Top 10 Important Features")

# Visualize the graph
plt.show()

# Save the figure
plt.savefig('Visualisation_of_Important_Features.png')

# %% [markdown]
# The Random Forest classifier in Sklearn contains a feature importances attribute which tells us which features within our dataset has been given most importance.The top three important features affecting the performance rating are as follows:
#
# 1. Employee Salary Hike Percentage
# 2. Employee Environment Satisfaction
# 3. Years Since the last Promotion

# %% [markdown]
# #REFERENCES
#
# Packages required for this project:
#
# 1. pandas
# 2. numpy
# 3. seaborn
# 4. matplotlib
# 5. sklearn
